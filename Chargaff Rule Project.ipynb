# %%
### Chargaff rule project

# %%
# analyse .fasta files of genome OF humans, Plasmodium falciparum, Anppheles gambiaeas
# calculate %A % C %G %T

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import IUPAC
from Bio.SeqUtils import GC
for seq_record in SeqIO.parse("human-PrR1jPIaAG.fasta", "fasta"):
    my_seq = Seq("...", IUPAC.unambiguous_dna)
    GC(my_seq)

# %%
# G % human Fasta
100 * float(my_seq.count("G")) / len(my_seq)
# Out:
# 21.138567130130387

# %%
# C % human Fasta 
100 * float(my_seq.count("C")) / len(my_seq)
# Out:
# 20.522035831579775

# %%
# A % human Fasta 
100 * float(my_seq.count("A")) / len(my_seq)
# Out:
# 29.07874294479734

# %%
# T % human Fasta 
100 * float(my_seq.count("T")) / len(my_seq)
# Out:
# 29.260654093492498

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import IUPAC
from Bio.SeqUtils import GC
for seq_record in SeqIO.parse("mosquito-AK2jNK0ahq.fasta", "fasta"):
    mos_seq = Seq("", IUPAC.unambiguous_dna)
# Out:
#   File "<ipython-input-1-9d934726d425>", line 5
#     for seq_record in SeqIO.parse("human-PrR1jPIaAG.fasta", "fasta"):
#                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
# G %  mosquito Fasta
100 * float(mos_seq.count("G")) / len(mos_seq)

# %%
# C %  mosquito Fasta
100 * float(mos_seq.count("C")) / len(mos_seq)

# %%
# A % mosquito Fasta 
100 * float(mos_seq.count("A")) / len(mos_seq)

# %%
# T % mosquito Fasta 
100 * float(mos_seq.count("T")) / len(mos_seq)

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import IUPAC
from Bio.SeqUtils import GC
for seq_record in SeqIO.parse("plasmodium-RkREaPiyih.fasta", "fasta"):
    pla_seq = Seq("", IUPAC.unambiguous_dna)

# %%
# G %  plasmodium Fasta
100 * float(pla_seq.count("G")) / len(pla_seq)

# %%
# C %  plasmodium Fasta
100 * float(pla_seq.count("C")) / len(pla_seq)

# %%
# A % plasmodium Fasta 
100 * float(pla_seq.count("A")) / len(pla_seq)

# %%
# T % plasmodium Fasta 
100 * float(pla_seq.count("T")) / len(pla_seq)

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import IUPAC
from Bio.SeqUtils import GC
for seq_record in SeqIO.parse("sarcovid2.fasta", "fasta"):
    corona_seq = Seq("", IUPAC.unambiguous_dna)

# %%
# G %  sarcovid2 Fasta
100 * float(corona_seq.count("G")) / len(corona_seq)

# %%
# C %  sarcovid2 Fasta
100 * float(corona_seq.count("C")) / len(corona_seq)

# %%
# A % sarcovid2 Fasta 
100 * float(corona_seq.count("A")) / len(corona_seq)

# %%
# T % sarcovid2 Fasta 
100 * float(corona_seq.count("T")) / len(corona_seq)
