# %%
sequence = ('...')

# %%
string_one = ""
string_one = sequence.replace('t', 'a').replace('c', 'g')
print (string_one)
string_two = ""
string_two = string_one.replace('a', 'u').replace('g', 'c')
print (string_two)
# Out:
# ...
# ...

# %%
complement = []

for i in range(len(sequence)):
    if sequence[i]  == 't':
        complement.append('a')
    elif sequence[i] == 'a':
        complement.append('u')
    elif sequence[i] == 'c':
        complement.append('g')
    elif sequence[i] == 'g':
        complement.append('c')
rna_complement = print("".join(complement)[::-1])        
rna_complement = "".join(complement)[::-1]
# Out:
# ...

# %%
my_dic = {'uuu':'F','uuc':'F','uua':'L','uug':'L',
           'ucu':'S','ucc':'S','uca':'S','ucg':'S','uau':'Y',
           'uac':'Y','uaa':'stop','uag':'stop','ugu':'C', 
           'ugc':'C','uga':'stop','ugg':'W','cuu':'L',
           'cuc':'L','cua':'L','cug':'L','ccu':'P','ccc':'P',
           'cca':'P','ccg':'P','cau':'H','cac':'H','caa':'Q',
           'cag':'Q','cgu':'R','cgc':'R','cga':'R','cgg':'R',
           'auu':'I','auc':'I','aua':'I','aug':'M','acu':'T',
           'acc':'T','aca':'T','acg':'T','aau':'N','aac':'N',
           'aaa':'K','aag':'K','agu':'S','agc':'S','aga':'R',
           'agg':'R','guu':'V','guc':'V','gua':'V','gug':'V',
           'gcu':'A','gcc':'A','gca':'A','gcg':'A','gau':'D',
           'gac':'D','gaa':'E','gag':'E','ggu':'G','ggc':'G',
           'gga':'G','ggg':'G'}

# %%
index = 0
while index <= len(rna_complement) - 3:
    three_split = rna_complement[index:index+3]
    index += 3
    #print(three_split)
#type(three_split) 'string'
    for keys,vals in my_dic.items():
           if keys == three_split:
                rna_codon = vals.split()
    print(rna_codon[0])
# Out:
# L
# V
# R
# F
# P
# R
# T
# T
# Q
# A
# R
# R
# L
# A
# E
# P
# P
# P
# R
# Q
# Q
# L
# F
# V
# P
# K
# Y
# stop
# A
# V
# D
# I
# stop
# M
# P
# H
# stop
# L
# Y
# P
# stop
# L
# P
# C
# I
# T
# G
# L
# I
# A
# S
# L
# L
# R
# P
# S
# S
# I
# I
# N
# E
# V
# G
# R
# V
# L
# T
# T
# L
# S
# V
# K
# D
# K
# N
# S
# G
# T
# R
# Q
# S
# C
# S
# T
# A
# F
# V
# T
# I
# Y
# Y
# stop
# A
# stop
# A
# S
# H
# N
# T
# A
# R
# G
# T
# L
# K
# G
# F
# I
# G
# A
# A
# C
# F
# S
# G
# E
# C
# V
# L
# S
# K
# A
# K
# V
# Q
# L
# S
# K
# M
# F
# A
# W
# V
# A
# E
# stop
# G
# A
# H
# R
# L
# D
# Y
# S
# L
# N
# stop
# C
# T
# T
# T
# Y
# V
# W
# Q
# A
# C
# T
# stop
# A
# K
# T
# L
# R
# K
# Q
# A
# T
# G
# D
# Y
# stop
# V
# R
# W
# G
# H
# G
# D
# L
# S
# A
# R
# A
# S
# S
# V
# R
# Y
# T
# R
# stop
# Y
# G
# P
# M
# D
# G
# R
# M
# A
# P
# I
# T
# T
# F
# K
# L
# L
# P
# A
# Y
# T
# V
# R
# E
# V
# G
# S
# I
# Y
# R
# stop
# N
# D
# K
# F
# T
# K
# C
# S
# G
# L
# I
# Y
# R
# I
# N
# I
# P
# V
# ...

# %%
# prove recreatre CHargaff experiment using python
# analyze fasta files for Humans, Plasmodium falciparum, Anopheles gambiaesas
# calculate %A %T %C %G
# Conclude froom the analysis

# %%
from Bio import SeqIO 
for record in SeqIO.parse("human-PrR1jPIaAG.fasta", "fasta"):
    print(record.id)
# Out:
# AC073210.8
